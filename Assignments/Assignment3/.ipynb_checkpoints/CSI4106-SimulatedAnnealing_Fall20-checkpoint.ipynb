# %% [markdown]
# # Notebook 3 - Simulated annealing for the TSP

# %% [markdown]
# CSI4106 Artificial Intelligence
# Fall 2020
# Prepared by Julian Templeton and Caroline Barrière

# %% [markdown]
# ***INTRODUCTION***:
#
# This homework will allow you to look deeper into one of the randomized searches presented in class, that of *Simulated Annealing*. It is a good example of a *random modification* algorithm, in which we start with a greedy solution, and then make changes and accept the modified solutions with different probabilities given their level of fitness to a cost function.
#
# The application domain for experimenting with *Simulated Annealing* is the traveling salesman problem (TSP), which is a classical problem of scheduling, with optimization on the cost of travel.
#
# The notebook will lead into the **Simulated Annealing** portion after exploring a **greedy approach** and a **randomized greedy approach**.

# %% [markdown]
# ***HOMEWORK***:
# Go through the notebook by running each cell, one at a time.
# Look for **(TO DO)** for the tasks that you need to perform. Do not edit the code outside of the questions which you are asked to answer unless specifically asked. Once you're done, sign the notebook (see the added step at the end), and submit it.
#
# *The notebook will be marked on 20.
# Each **(TO DO)** has a number of points associated with it.*
# ***

# %% [markdown]
# **1. Let's start with a small set of cities.**

# %%
# let's define 5 cities with a label and a (x,y) coordinate
cities = {'A': (0,0), 'B': (1,1), 'C': (1,0), 'D': (1,-1), 'E': (-1,-1)}

# %% [markdown]
# Let's plot the nodes using the *showNodes* method below.
# The packages matplotlib, networkx, and numpy must be installed first.
# To do so, open a command prompt and type **pip install numpy** and **pip install networkx** (If you are using linux or potentially Mac, you may need to use **pip3** rather than **pip** depending on how you set it up). You should already have matplotlib, but if not use the pip command **pip install matplotlib**. After installing the packages, run the cell below. If it does not work, restart the Kernel and run through it again to be able to run the cell.

# %%
import matplotlib.pyplot as plt
import networkx as nx

# small method to show nodes
# provide defaults for figure size (size), as well as x and y axis
def showNodes(nodeDict, size= (6.5, 4), xLim=[-2,2], yLim=[-2,2]):
    fig = plt.figure(figsize=size)
    axg = fig.add_subplot(111)
    axg.set_xlim(xLim)
    axg.set_ylim(yLim)

    G=nx.Graph()
    for k in nodeDict.keys():
        G.add_node(k, coor=nodeDict.get(k))
    
    pos=nx.get_node_attributes(G,'coor')
    nx.draw(G, pos, with_labels = True)
    plt.axis('on')
    plt.show()

# %%
# show the cities on a map
showNodes(cities)

# %% [markdown]
# #### 2. Let's find the distances between all cities.
# First, we define a method to calculate the distance between two specific cities, and then a method to find the distances between all pairs of nodes.

# %%
import math

# returns the euclidian distance between two nodes
def dist(node1, node2):
    return round(math.sqrt(math.pow(node1[0] - node2[0], 2) + math.pow(node1[1] - node2[1], 2)), 3)

# %%
# Small test to see the distance
dist(cities.get('A'), cities.get('B'))
# Out:
# 1.414

# %%
# building a dictionary of all pairs or distances
def distDict(nodes):
    distance = {}
    # go through all pairs of nodes
    for k in nodes.keys():
        for m in nodes.keys():
            distance[k,m] = dist(nodes.get(k), nodes.get(m))
    return distance

# %%
# showing the distances between the cities
distances = distDict(cities)
print(distances)
# Out:
# {('A', 'A'): 0.0, ('A', 'B'): 1.414, ('A', 'C'): 1.0, ('A', 'D'): 1.414, ('A', 'E'): 1.414, ('B', 'A'): 1.414, ('B', 'B'): 0.0, ('B', 'C'): 1.0, ('B', 'D'): 2.0, ('B', 'E'): 2.828, ('C', 'A'): 1.0, ('C', 'B'): 1.0, ('C', 'C'): 0.0, ('C', 'D'): 1.0, ('C', 'E'): 2.236, ('D', 'A'): 1.414, ('D', 'B'): 2.0, ('D', 'C'): 1.0, ('D', 'D'): 0.0, ('D', 'E'): 2.0, ('E', 'A'): 1.414, ('E', 'B'): 2.828, ('E', 'C'): 2.236, ('E', 'D'): 2.0, ('E', 'E'): 0.0}

# %%
# find the min distance from node1 to all other nodes.
# it receives the node1 label, the labels of other nodes to test,
# and the precalculated distances between all nodes
def closestNode(node1_label, otherNodes_Labels, distanceDict):
    # tricky syntax... it creates tuples where the distance is the first element of the tuple
    # and the position in the array is the second element of the tuple
    minDist = min( (distanceDict[node1_label,k], k) for k in otherNodes_Labels)
    # get the second element of the tuple which is the index found
    foundNode = minDist[1]
    return foundNode

# %%
# Testing the closest node
closestNode('B', ['C', 'D'], distances)
# Out:
# 'C'

# %% [markdown]
# #### 3. Greedy solution first
# Before we can apply *simulated annealing*, we must first find a suboptimal solution that we will refine. The first solution will be a Greedy solution. Only the choice of the starting node is random in this solution, and from there, the algorithm always choses the closest node.

# %%
# greedy solution
import random

def greedy_solution(nodes):
    # distance matrix
    allDist = distDict(nodes)
    # pick a first node at random among the set of keys (node names)
    cur_node = random.choice(list(nodes.keys()))
    # add that node to solution
    solution = [cur_node]
    # build a free list of nodes (not yet used) containing all nodes except the one just chosen 
    free_list = list(nodes.keys())
    free_list.remove(cur_node)
    
    # while there are still nodes to be attached
    while free_list:
        # find the closestNode
        found_node = closestNode(cur_node, free_list, allDist)
        cur_node = found_node
        free_list.remove(cur_node)
        solution.append(cur_node)

    return solution

# %%
# Test obtaining a greedy solution
gs = greedy_solution(cities)
print(gs)
# Out:
# ['E', 'A', 'C', 'B', 'D']

# %% [markdown]
# #### 4. Showing a path.
# We slightly modify to showNodes method from before, to become showPath, wich is now a directed graph.

# %%
# small method to show a path
# it receives an ordered list of nodes e.g. ['B','C','A', 'D', 'E']
# and a dictionary of all the nodes and their positions
def showPath(path, nodeDict, size= (6.5, 4), xLim=[-2,2], yLim=[-2,2]):
    fig = plt.figure(figsize=size)
    axg = fig.add_subplot(111)
    axg.set_xlim(xLim)
    axg.set_ylim(yLim)

    G=nx.DiGraph()
    for k in path:
        G.add_node(k, pos=nodeDict.get(k))
        
    for i in range(len(path) - 1):
        x = path[i]
        y = path[i + 1]
        G.add_edge(x,y)
        
    pos=nx.get_node_attributes(G,'pos')
    nx.draw(G, pos, with_labels = True, edge_color = 'b', arrows=True)   
    # nx.draw(G, pos, with_labels = True)
    plt.axis('on')
    plt.show()

# %% [markdown]
# **(TO DO) Q1 - 2 marks**
# 1. Select a seed (integer) to use in the cell below
# 2. Run that cell to set the seed (only once)
# 3. Run the tests below the seed declaration repeatedly (just manually run it) until you get two identical results in the same run. Record how many runs it took and the solution found in the answer section below.
# 4. Run the tests below the seed declaration repeatedly (just manually run it) until you get two different results in the same run. Record how many runs it took and the solution found in the answer section below.

# %% [markdown]
# **(ANSWER in this Markdown) Q1**
# Nb of runs needed to generate an identical gs1 and gs2 :  two runs
# Solution generated for the identical gs1 and gs2 : ['B', 'C', 'A', 'D', 'E']
#
# Nb of runs needed to generate a different gs1 and gs2 :  one run
# Solutions generated for the distinct gs1 and gs2 : ['A', 'C', 'B', 'D', 'E']
#                                                    ['D', 'C', 'A', 'B', 'E']

# %% [markdown]
# Setup the seed:

# %%
# To Do: Place your seed here and run the cell to set/reset it
# random.seed(int)
random.seed()

# %% [markdown]
# Let us run a test to visualize two greedy solutions. Look at the text output of the path if the plotted graph contains edges that go through a node.

# %%
# To Do: Need to run this (make no changes) and answer the questions above

# Testing to output the path chosen by the greedy solution
gs1 = greedy_solution(cities)
print(gs1)
showPath(gs1, cities)
gs2 = greedy_solution(cities)
print(gs2)
showPath(gs2, cities)
# Out:
# ['A', 'C', 'B', 'D', 'E']
# ['D', 'C', 'A', 'B', 'E']

# %% [markdown]
# **(TO DO) Q2 - 2 marks**
# Complete the method to find the total length of the path found.

# %%
# (TO DO) totalDistance, which receives a path (list of node labels) and the dictionary of distances
def totalDist(path, distanceDict):
    total = 0
    for i in range(len(path) - 1):
        x = path[i]
        y = path[i + 1]
        distance = distanceDict[y,x]
        total += distance
    return round(total,3)

# %%
# Test the total distance method
print(totalDist(gs1, distances))
print(totalDist(gs2, distances))
# Out:
# 6.0
# 6.242

# %% [markdown]
# **(TO DO) Q3 - 4 marks**
# Add two more cities (wherever you want within the predefined -2 to +2 axis as long as no other node is already there).  Rerun the full sequence of tasks performed above on the larger set of cities that you will define below: (1) defining the graph (2) showing the points (3) building the distance dictionary, (4) finding two unique greedy solutions, (5) showing the different paths found along with their total distances.

# %%
# (1) Defining a larger set of cities  (add two more)
moreCities = {'A': (0,0), 'B': (1,1), 'C': (1,0), 'D': (1,-1), 'E': (-1,-1), 'F': (-1,0), 'G': (-1,1)}
# (2) Show the points
showNodes(moreCities)
# (3) Build the distance dictionary
moreDistances = distDict(moreCities)
print(moreDistances)
# (4) Find two unique greedy solutions 
gs1_U = greedy_solution(moreCities)
print(gs1_U)
gs2_U = greedy_solution(moreCities)
print(gs2_U)
# (5) Show the two unique paths found above along with their total distances
showPath(gs1_U, moreCities)
print(totalDist(gs1_U, moreDistances))
showPath(gs2_U, moreCities)
print(totalDist(gs2_U, moreDistances))
# Out:
# {('A', 'A'): 0.0, ('A', 'B'): 1.414, ('A', 'C'): 1.0, ('A', 'D'): 1.414, ('A', 'E'): 1.414, ('A', 'F'): 1.0, ('A', 'G'): 1.414, ('B', 'A'): 1.414, ('B', 'B'): 0.0, ('B', 'C'): 1.0, ('B', 'D'): 2.0, ('B', 'E'): 2.828, ('B', 'F'): 2.236, ('B', 'G'): 2.0, ('C', 'A'): 1.0, ('C', 'B'): 1.0, ('C', 'C'): 0.0, ('C', 'D'): 1.0, ('C', 'E'): 2.236, ('C', 'F'): 2.0, ('C', 'G'): 2.236, ('D', 'A'): 1.414, ('D', 'B'): 2.0, ('D', 'C'): 1.0, ('D', 'D'): 0.0, ('D', 'E'): 2.0, ('D', 'F'): 2.236, ('D', 'G'): 2.828, ('E', 'A'): 1.414, ('E', 'B'): 2.828, ('E', 'C'): 2.236, ('E', 'D'): 2.0, ('E', 'E'): 0.0, ('E', 'F'): 1.0, ('E', 'G'): 2.0, ('F', 'A'): 1.0, ('F', 'B'): 2.236, ('F', 'C'): 2.0, ('F', 'D'): 2.236, ('F', 'E'): 1.0, ('F', 'F'): 0.0, ('F', 'G'): 1.0, ('G', 'A'): 1.414, ('G', 'B'): 2.0, ('G', 'C'): 2.236, ('G', 'D'): 2.828, ('G', 'E'): 2.0, ('G', 'F'): 1.0, ('G', 'G'): 0.0}
# ['E', 'F', 'A', 'C', 'B', 'D', 'G']
# ['D', 'C', 'A', 'F', 'E', 'G', 'B']
# 8.828
# 8.0

# %% [markdown]
# **5. Randomized Greedy - Setup**
#
# Before we create our Randomized Greedy solution, we will define a new function called kClosestNodes that will return the k-closest nodes to a given node.

# %%
# find the min distance from node1 to all other nodes.
# it receives the node1 label, the labels of other nodes to test,
# the precalculated distances between all nodes, and k for how many to return
# The function then outputs a list of the k-closest nodes, where the
# first is the closest and the kth is the kth-closest
def kClosestNodes(node1_label, otherNodes_Labels, distanceDict, k):
    kClosest = []
    # Create a sorted distance list based on the values from the distance dictionary
    # This has the form [((node_1, node_2),value_1), ..., ((node_n, node_n), value_n)]
    sortedDistances = sorted(distanceDict.items(), key=lambda keyPair: keyPair[1])
    # Iterate through the sorted distance list to find our k min distances
    # from node1_label
    for key, value in sortedDistances:
        if (k > 0 and key[0] == node1_label and key[1] in otherNodes_Labels):
            k -= 1
            kClosest.append(key[1])
    return kClosest

# %%
# Example usage
# View the distance dictionary to verify correctness when finding the closest nodes
# to node B in cities
print(distances)
# Find the two closest nodes to the node B in cities (using its distance dictionary)
kClosestNodes('B', ['A', 'C', 'D', 'E'], distances, 2)
# Out:
# {('A', 'A'): 0.0, ('A', 'B'): 1.414, ('A', 'C'): 1.0, ('A', 'D'): 1.414, ('A', 'E'): 1.414, ('B', 'A'): 1.414, ('B', 'B'): 0.0, ('B', 'C'): 1.0, ('B', 'D'): 2.0, ('B', 'E'): 2.828, ('C', 'A'): 1.0, ('C', 'B'): 1.0, ('C', 'C'): 0.0, ('C', 'D'): 1.0, ('C', 'E'): 2.236, ('D', 'A'): 1.414, ('D', 'B'): 2.0, ('D', 'C'): 1.0, ('D', 'D'): 0.0, ('D', 'E'): 2.0, ('E', 'A'): 1.414, ('E', 'B'): 2.828, ('E', 'C'): 2.236, ('E', 'D'): 2.0, ('E', 'E'): 0.0}
# ['C', 'A']

# %% [markdown]
# **6. Randomized Greedy**
#
# Next you will find another suboptimal solution that we will refine. This second solution will be a Randomized Greedy solution.

# %% [markdown]
# **(TO DO) Q4 - 5 marks**
# The Randomized Greedy solution that you will create still selects a random first node, but should now pick randomly among the k closest nodes available, given a probability distribution (rather than the closest node).
#
# For example, if you found the five closest nodes when looking for which to add next, you would randomly choose one of them where the closest nodes would have a higher probability of being chosen then the nodes that are not as close.
#
# The probability distribution for a set of node distances is given by the function *normalize* below and finding the k-closest nodes is given from the kClosestNodes function above. You must call both of these functions in your solution and follow the general structure defined by the comments.
#
# After finishing the function, add one more test to the tests below with a different value for k

# %%
import random
import numpy as np

# DO NOT EDIT THIS FUNCTION
# nodeFrom is the node we start at, nodesTo is a list of nodes
# that nodeFrom can go to, and distDict is the dictionary of all
# combinations of distances.
# This provides the probability distribution to be used by
# randomized_greedy_solution
def normalize(nodeFrom, nodesTo, distDict):
    distances = []
    # Here we normalize by 1/distance^2 
    for nodeTo in nodesTo:
        distances.append(1 / distDict[nodeFrom, nodeTo] ** 2)
    sumOfDistances = sum(distances)
    normalizedDistances = [dist / sumOfDistances for dist in distances]
    return normalizedDistances
    
# k represents the number of closest nodes to be returned from the
# function kClosestNodes
def randomized_greedy_solution(nodes, k):
    # distance matrix
    allDist = distDict(nodes)
    # pick a first node at random among the set of keys (node names)
    cur_node = random.choice(list(nodes.keys()))
    # add that node to solution
    solution = [cur_node]
    # build a free list of nodes (not yet used) containing all nodes except the one just chosen 
    free_list = list(nodes.keys())
    free_list.remove(cur_node)
    
    # while there are still nodes to be attached
    
    while free_list:
        
        # TO DO START: Complete the algorithm by performing what the comments ask
        
        # Get the closest nodes
        k_selected = kClosestNodes(cur_node, free_list, allDist, k)
        
        # Find the normalized distances
        prob_list = normalize(cur_node, k_selected, allDist)
        
        # Select a random closest node based on the probabilities found by the normalized distances
        # You will use the function np.random.choice(options, list_of_probabilities_for_options)
        # For more information on np.random.choice check out the official documentation:
        #      https://docs.scipy.org/doc/numpy-1.15.0/reference/generated/numpy.random.choice.html#numpy.random.choice
        found_node_list = np.random.choice(k_selected, 1, prob_list)
        found_node = found_node_list[0]
        # Print out the probabilities for each closest node choice (just output both lists saying what they are)
        for i in range(len(k_selected)):
            print('The closest node is:', k_selected[i], 'and its probability is:', round(prob_list[i],3))
            
        
        # Print out the closest node selected by the probability distribution with it's probability of being selected
        for j in range(len(k_selected)):
            if found_node == k_selected[j]:
                print('The closest node selected by the probability distribution is:', found_node)
                print('And the probability of being selected is', round(prob_list[j],3)) 
        
        # TO DO END
        
        # Same as in the Greedy approach
        cur_node = found_node
        free_list.remove(cur_node)
        solution.append(cur_node)

    return solution

# %%
# Testing to output the path chosen by the randomized greedy solution with various k's to the greedy solution
# Run a few times to see how the results differ with the non-deterministic Randomized Greedy solution
# Note that if they start with the same node and k=1 that the results of both will be the same
print("Greedy Test")
gr = greedy_solution(moreCities)
print(gr)
print(totalDist(gr, moreDistances))
showPath(gr, moreCities)
print("Randomized Greedy Test")
rgs1 = randomized_greedy_solution(moreCities, 1)
print(rgs1)
print(totalDist(rgs1, moreDistances))
showPath(rgs1, moreCities)
print("Randomized Greedy Test")
rgs2 = randomized_greedy_solution(moreCities, 2)
print(rgs2)
print(totalDist(rgs2, moreDistances))
showPath(rgs2, moreCities)
# TO DO: Add one more test randomized_greedy_solution with a different k
print("Randomized Greedy Test")
rgs3 = randomized_greedy_solution(moreCities, 3)
print(rgs3)
print(totalDist(rgs3, moreDistances))
showPath(rgs3, moreCities)
# Out:
# Greedy Test
# ['F', 'A', 'C', 'B', 'D', 'E', 'G']
# 9.0
# Randomized Greedy Test
# The closest node is: F and its probability is: 1.0
# The closest node selected by the probability distribution is: F
# And the probability of being selected is 1.0
# The closest node is: A and its probability is: 1.0
# The closest node selected by the probability distribution is: A
# And the probability of being selected is 1.0
# The closest node is: C and its probability is: 1.0
# The closest node selected by the probability distribution is: C
# And the probability of being selected is 1.0
# The closest node is: B and its probability is: 1.0
# The closest node selected by the probability distribution is: B
# And the probability of being selected is 1.0
# The closest node is: D and its probability is: 1.0
# The closest node selected by the probability distribution is: D
# And the probability of being selected is 1.0
# The closest node is: E and its probability is: 1.0
# The closest node selected by the probability distribution is: E
# And the probability of being selected is 1.0
# ['G', 'F', 'A', 'C', 'B', 'D', 'E']
# 8.0
# Randomized Greedy Test
# The closest node is: A and its probability is: 0.5
# The closest node is: E and its probability is: 0.5
# The closest node selected by the probability distribution is: E
# And the probability of being selected is 0.5
# The closest node is: A and its probability is: 0.667
# The closest node is: D and its probability is: 0.333
# The closest node selected by the probability distribution is: D
# And the probability of being selected is 0.333
# The closest node is: C and its probability is: 0.667
# The closest node is: A and its probability is: 0.333
# The closest node selected by the probability distribution is: A
# And the probability of being selected is 0.333
# The closest node is: C and its probability is: 0.667
# The closest node is: B and its probability is: 0.333
# The closest node selected by the probability distribution is: B
# And the probability of being selected is 0.333
# The closest node is: C and its probability is: 0.8
# The closest node is: G and its probability is: 0.2
# The closest node selected by the probability distribution is: C
# And the probability of being selected is 0.8
# The closest node is: G and its probability is: 1.0
# The closest node selected by the probability distribution is: G
# And the probability of being selected is 1.0
# ['F', 'E', 'D', 'A', 'B', 'C', 'G']
# 9.064
# Randomized Greedy Test
# The closest node is: C and its probability is: 0.4
# The closest node is: F and its probability is: 0.4
# The closest node is: B and its probability is: 0.2
# The closest node selected by the probability distribution is: F
# And the probability of being selected is 0.4
# The closest node is: E and its probability is: 0.444
# The closest node is: G and its probability is: 0.444
# The closest node is: C and its probability is: 0.111
# The closest node selected by the probability distribution is: E
# And the probability of being selected is 0.444
# The closest node is: D and its probability is: 0.357
# The closest node is: G and its probability is: 0.357
# The closest node is: C and its probability is: 0.286
# The closest node selected by the probability distribution is: D
# And the probability of being selected is 0.357
# The closest node is: C and its probability is: 0.727
# The closest node is: B and its probability is: 0.182
# The closest node is: G and its probability is: 0.091
# The closest node selected by the probability distribution is: C
# And the probability of being selected is 0.727
# The closest node is: B and its probability is: 0.833
# The closest node is: G and its probability is: 0.167
# The closest node selected by the probability distribution is: G
# And the probability of being selected is 0.167
# The closest node is: B and its probability is: 1.0
# The closest node selected by the probability distribution is: B
# And the probability of being selected is 1.0
# ['A', 'F', 'E', 'D', 'C', 'G', 'B']
# 9.236

# %% [markdown]
# **7. Defining the process of simulated annealing**
# The class below defines the simulated annealing process.  This class is an adaptation of the class anneal.py found in the python code provided in this github https://github.com/chncyhn/simulated-annealing-tsp. You are not asked to changed this class, just go through it and try to understand it so as to get a better understanding of the *simulated annealing* algorithm.

# %%
# class to perform a simulated annealing
# must start with a set of nodes, all other parameters have defaults
class SimAnneal(object):
    def __init__(self, nodes, randomizedGreedy, k=4, T=-1, alpha=-1, stopping_T=-1, stopping_iter=-1):
        # set of nodes
        self.nodes = nodes
        # number of nodes
        self.N = len(nodes)
        # set the temperature T to sqrt(N) if not specified
        self.T = math.sqrt(self.N) if T == -1 else T
        # set alpha (rate at which the temperature is decreased)
        self.alpha = 0.995 if alpha == -1 else alpha
        # set stopping temprature
        self.stopping_temperature = 0.00000001 if stopping_T == -1 else stopping_T
        # set stopping iteration
        self.stopping_iter = 100000 if stopping_iter == -1 else stopping_iter
        # start at iteration 1
        self.iteration = 1

        # calculate the distances
        self.allDist = distDict(nodes)
        
        # start with greedy solution if randomizedGreedy is false,
        #  start with the randomized greedy solution if randomizedGreedy is true
        if (randomizedGreedy):
            self.cur_solution = randomized_greedy_solution(nodes, k)
            self.improvementMessage = 'Improvement over randomized greedy heuristic: '
        else:
            self.cur_solution = greedy_solution(nodes)
            self.improvementMessage = 'Improvement over greedy heuristic: '
        
        # so far, the best solution is the one we have
        self.best_solution = list(self.cur_solution)

        # calculate fitness of the current solution
        self.cur_fitness = self.fitness(self.cur_solution)
        # initial fitness for initial solution
        self.initial_fitness = self.cur_fitness
        # best fitness so far
        self.best_fitness = self.cur_fitness
        # build the fitness list as we explore solutions
        self.fitness_list = [self.cur_fitness]


    def fitness(self, sol):
        """ Objective value of a solution """
        return totalDist(sol, self.allDist)

    # acceptance propability
    def p_accept(self, candidate_fitness):
        """
        Probability of accepting if the candidate is worse than current
        Depends on the current temperature and difference between candidate and current
        """
        return math.exp(-abs(candidate_fitness - self.cur_fitness) / self.T)

    def accept(self, candidate):
        """
        Accept with probability 1 if candidate is better than current
        Accept with probabilty p_accept(..) if candidate is worse
        """
        candidate_fitness = self.fitness(candidate)
        # test if fitness is smaller then the current one
        if candidate_fitness < self.cur_fitness:
            self.cur_fitness = candidate_fitness
            self.cur_solution = candidate
            # test if fitness is better than best so far, keep it as best if so
            if candidate_fitness < self.best_fitness:
                self.best_fitness = candidate_fitness
                self.best_solution = candidate

        # if solution is worst than the current one, there is still a possibility to pursue it
        else:
            if random.random() < self.p_accept(candidate_fitness):
                self.cur_fitness = candidate_fitness
                self.cur_solution = candidate

    def anneal(self):
        """
        Execute simulated annealing algorithm
        """
        # go through the temperature schedule
        print(self.T)
        print(self.stopping_temperature)
        while (self.T >= self.stopping_temperature) and (self.iteration < self.stopping_iter):
            # explore current solution
            candidate = list(self.cur_solution)
            # modify the solution to switch two cities
            # first chosen city between [2,N-1] - not changing the first city
            l = random.randint(2, self.N - 1)
            # second city between [0,N-1] Not sure why ??
            i = random.randint(0, self.N - l)
            # the chosen nodes are switch
            candidate[i:(i + l)] = reversed(candidate[i:(i + l)])
            # perform acceptance test 
            self.accept(candidate)
            # multiply the temperature by alpha (this will reduce it)
            self.T *= self.alpha
            self.iteration += 1
            
            # add current fitness to list (to be able to display)
            self.fitness_list.append(self.cur_fitness)

        print('Best fitness obtained: ', self.best_fitness)
        print(self.improvementMessage,
              round((self.initial_fitness - self.best_fitness) / (self.initial_fitness), 4))

        return self.best_solution
    
    def plot_learning(self):
        """
        Plot the fitness through iterations
        """
        plt.plot([i for i in range(len(self.fitness_list))], self.fitness_list)
        plt.ylabel('Fitness')
        plt.xlabel('Iteration')
        plt.show()

# %% [markdown]
# #### 8. Refining a greedy solution through simulated annealing.

# %% [markdown]
# **(TO DO) Q5 - 5 marks**
# Put comments in the code below explaining what it does.  Also run it a few times.  It will show you how there can be improvement (or not) from the greedy solution and randomized greedy solution to the annealed one.

# %%
# In the first attempt, we start with greedy solution to achieve a complete solution before doing any randomized modification 
# to our solution. The "greedy_solution" function takes the list of "moreCities" and in this way it gets the label of the name
# of cities.

firstSol = greedy_solution(moreCities)


# then we find the distances between each pair of cities (nodes) by calling "distDict" function. All the caluclated
# distances are saved in a dictonary.

distances = distDict(moreCities)


# the "greedy_solution" list is printed as the first solution for the TSP. The total distance for this solution
# is caluclated by calling "totalDist" function that uses the labels from "firstSol" 
# list and gets "distances" from the "distDict" dictionary.

print('Solution {} takes a total of {}'.format(firstSol,totalDist(firstSol, distances)))


# Then the path that is found and stored in "firstSol" is shown in a directed graph.

showPath(firstSol, moreCities)

## -------------------------------------------------------------------------------------------

# the simulated annealing approach gets the nodes form the "moreCities" list. The "randomizedGreedy" solution is considered 
#false here. This means the simulated annealing algorithm will start with greedy solution. The results from "Simulated
#Annealing" algorithem is stored in "sa" variable. 

sa = SimAnneal(moreCities, False)


# the anneal function from "SimAnneal" class is called to proceed with annealing process on the obtained solution from the
# greedy soution. The best fitness obtained and the Improvement over greedy heuristic (ratio of distance improvement ) 
#will be printed. 

betterSol = sa.anneal()


# at the end, the path that "stimulated anealing" method found is shown in a directed graph.

showPath(betterSol, moreCities)

##--------------------------------------------------------------------------------------------

# In the second attempt, we start with randomized greedy solution as a solution for the TSP, before doing any randomized
#modification to our solution. The "randomized_greedy_solution" function takes the list of "moreCities" and the k closest 
# nodes (here k =4) will be chosen. The function randomized_greedy_solution receives the mutual distances between cities 
# from "moreCities" list. 

secondSol = randomized_greedy_solution(moreCities, 4)

# the "randomized_greedy_solution" list is printed as the second solution for the TSP. The total distance for this solution
# is caluclated by calling "totalDist" function that uses the labels from "secondSol" 
# list and gets "distances" from the "distDict" dictionary.

print('Solution {} takes a total of {}'.format(secondSol,totalDist(secondSol, distances)))

# Then the path that is found and stored in "secondSol" is shown in a directed graph.

showPath(secondSol, moreCities)

##-------------------------------------------------------------------------------------------

# the simulated annealing approach gets the nodes form the "moreCities" list. The "randomizedGreedy" solution is considered 
#true here. This means annealing will start with randomized greedy solution. The results from 
#"Simulated Annealing" algorithem is stored in "sa2" variable. 

sa2 = SimAnneal(moreCities, True, 4)

# the anneal function from "SimAnneal" class is called to proceed with annealing process on the obtained solution from the
# randomized greedy soution. The best fitness obtained and the Improvement over greedy heuristic (ratio of distance improvement) 
#will be printed. 

betterSol2 = sa2.anneal()

# at the end, the path that "stimulated anealing" method found is shown in a directed graph.

showPath(betterSol2, moreCities)
# Out:
# Solution ['E', 'F', 'A', 'C', 'B', 'D', 'G'] takes a total of 8.828
# 2.6457513110645907
# 1e-08
# Best fitness obtained:  6.828
# Improvement over greedy heuristic:  0.1465
# The closest node is: A and its probability is: 0.308
# The closest node is: E and its probability is: 0.308
# The closest node is: G and its probability is: 0.308
# The closest node is: C and its probability is: 0.077
# The closest node selected by the probability distribution is: E
# And the probability of being selected is 0.308
# The closest node is: A and its probability is: 0.417
# The closest node is: D and its probability is: 0.208
# The closest node is: G and its probability is: 0.208
# The closest node is: C and its probability is: 0.167
# The closest node selected by the probability distribution is: A
# And the probability of being selected is 0.417
# The closest node is: C and its probability is: 0.4
# The closest node is: B and its probability is: 0.2
# The closest node is: D and its probability is: 0.2
# The closest node is: G and its probability is: 0.2
# The closest node selected by the probability distribution is: C
# And the probability of being selected is 0.4
# The closest node is: B and its probability is: 0.455
# The closest node is: D and its probability is: 0.455
# The closest node is: G and its probability is: 0.091
# The closest node selected by the probability distribution is: D
# And the probability of being selected is 0.455
# The closest node is: B and its probability is: 0.667
# The closest node is: G and its probability is: 0.333
# The closest node selected by the probability distribution is: B
# And the probability of being selected is 0.667
# The closest node is: G and its probability is: 1.0
# The closest node selected by the probability distribution is: G
# And the probability of being selected is 1.0
# Solution ['F', 'E', 'A', 'C', 'D', 'B', 'G'] takes a total of 8.414
# The closest node is: F and its probability is: 0.5
# The closest node is: A and its probability is: 0.25
# The closest node is: B and its probability is: 0.125
# The closest node is: E and its probability is: 0.125
# The closest node selected by the probability distribution is: E
# And the probability of being selected is 0.125
# The closest node is: F and its probability is: 0.513
# The closest node is: A and its probability is: 0.256
# The closest node is: D and its probability is: 0.128
# The closest node is: C and its probability is: 0.103
# The closest node selected by the probability distribution is: A
# And the probability of being selected is 0.256
# The closest node is: C and its probability is: 0.333
# The closest node is: F and its probability is: 0.333
# The closest node is: B and its probability is: 0.167
# The closest node is: D and its probability is: 0.167
# The closest node selected by the probability distribution is: C
# And the probability of being selected is 0.333
# The closest node is: B and its probability is: 0.444
# The closest node is: D and its probability is: 0.444
# The closest node is: F and its probability is: 0.111
# The closest node selected by the probability distribution is: B
# And the probability of being selected is 0.444
# The closest node is: D and its probability is: 0.556
# The closest node is: F and its probability is: 0.444
# The closest node selected by the probability distribution is: F
# And the probability of being selected is 0.444
# The closest node is: D and its probability is: 1.0
# The closest node selected by the probability distribution is: D
# And the probability of being selected is 1.0
# 2.6457513110645907
# 1e-08
# Best fitness obtained:  6.828
# Improvement over randomized greedy heuristic:  0.3093

# %% [markdown]
# **9. Moving toward a larger example**
# There are a set of coordinates defined in the file *coord.txt* (available in the Jupyter Notebooks module in Brightspace). This data file is also from the github https://github.com/chncyhn/simulated-annealing-tsp.  It contains a larger example with 45 cities, to test.  Here is the beginning of the file:
#
# 1 0 0
# 2 3 5
# 3 2.5 9
# 4 48 16
# 5 48 17
# 6 69 16
# ...
#
# Make sure to put the file *coord.txt* in the same repertory as your notebook or modify the path below when opening the file to read.  We will assume the first number is the label, and the other two numbers are the coordinates.

# %%
# reading the coordinates
manyCities = {}
with open('coord.txt','r') as f:
    i = 0
    for line in f.readlines():
        line = [float(x.replace('\n','')) for x in line.split(' ')]
        label = str(int(line[0]))
        manyCities[label] = (line[1], line[2])
        i += 1

# %% [markdown]
# Show the nodes from that larger set of cities.

# %%
showNodes(manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])

# %% [markdown]
# Testing the annealing process with the larger example. The steps are the same as the ones you had to comment in Question 4. Look at the additional step *plot_learning*, it shows the value of the fitness function as the annealing process occurs.  Run it multiple times, it is a probabilistic approach, so the result might be slightly different each time.

# %%
firstSol = greedy_solution(manyCities)
distances = distDict(manyCities)
print('Solution {} takes a total of {}'.format(firstSol,totalDist(firstSol, distances)))
showPath(firstSol, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])

sa = SimAnneal(manyCities, False)
betterSol = sa.anneal()
sa.plot_learning()
showPath(betterSol, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])

secondSol = randomized_greedy_solution(manyCities, 3)
print('Solution {} takes a total of {}'.format(secondSol,totalDist(secondSol, distances)))
showPath(firstSol, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])

sa2 = SimAnneal(manyCities, True, 4)
betterSol2 = sa2.anneal()
sa2.plot_learning()
showPath(betterSol2, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])
# Out:
# Solution ['37', '43', '39', '38', '2', '16', '10', '25', '1', '17', '3', '11', '18', '19', '12', '13', '15', '14', '21', '22', '9', '20', '26', '27', '23', '24', '45', '44', '31', '42', '41', '40', '35', '32', '33', '34', '30', '28', '7', '6', '8', '36', '4', '5', '29'] takes a total of 606.695
# 6.708203932499369
# 1e-08
# Best fitness obtained:  500.059
# Improvement over greedy heuristic:  0.2013
# The closest node is: 24 and its probability is: 0.666
# The closest node is: 27 and its probability is: 0.333
# The closest node is: 26 and its probability is: 0.001
# The closest node selected by the probability distribution is: 27
# And the probability of being selected is 0.333
# The closest node is: 24 and its probability is: 0.99
# The closest node is: 26 and its probability is: 0.007
# The closest node is: 20 and its probability is: 0.003
# The closest node selected by the probability distribution is: 24
# And the probability of being selected is 0.99
# The closest node is: 26 and its probability is: 0.558
# The closest node is: 20 and its probability is: 0.285
# The closest node is: 21 and its probability is: 0.157
# The closest node selected by the probability distribution is: 21
# And the probability of being selected is 0.157
# The closest node is: 22 and its probability is: 0.995
# The closest node is: 1 and its probability is: 0.002
# The closest node is: 25 and its probability is: 0.002
# The closest node selected by the probability distribution is: 1
# And the probability of being selected is 0.002
# The closest node is: 25 and its probability is: 1.0
# The closest node is: 10 and its probability is: 0.0
# The closest node is: 16 and its probability is: 0.0
# The closest node selected by the probability distribution is: 10
# And the probability of being selected is 0.0
# The closest node is: 16 and its probability is: 0.8
# The closest node is: 25 and its probability is: 0.138
# The closest node is: 2 and its probability is: 0.062
# The closest node selected by the probability distribution is: 16
# And the probability of being selected is 0.8
# The closest node is: 25 and its probability is: 0.511
# The closest node is: 2 and its probability is: 0.407
# The closest node is: 3 and its probability is: 0.083
# The closest node selected by the probability distribution is: 2
# And the probability of being selected is 0.407
# The closest node is: 3 and its probability is: 0.533
# The closest node is: 25 and its probability is: 0.256
# The closest node is: 17 and its probability is: 0.211
# The closest node selected by the probability distribution is: 17
# And the probability of being selected is 0.211
# The closest node is: 3 and its probability is: 0.715
# The closest node is: 25 and its probability is: 0.171
# The closest node is: 11 and its probability is: 0.114
# The closest node selected by the probability distribution is: 3
# And the probability of being selected is 0.715
# The closest node is: 25 and its probability is: 0.6
# The closest node is: 11 and its probability is: 0.212
# The closest node is: 18 and its probability is: 0.188
# The closest node selected by the probability distribution is: 25
# And the probability of being selected is 0.6
# The closest node is: 22 and its probability is: 0.64
# The closest node is: 11 and its probability is: 0.216
# The closest node is: 38 and its probability is: 0.144
# The closest node selected by the probability distribution is: 11
# And the probability of being selected is 0.216
# The closest node is: 18 and its probability is: 0.516
# The closest node is: 19 and its probability is: 0.399
# The closest node is: 22 and its probability is: 0.085
# The closest node selected by the probability distribution is: 19
# And the probability of being selected is 0.399
# The closest node is: 18 and its probability is: 0.801
# The closest node is: 12 and its probability is: 0.12
# The closest node is: 22 and its probability is: 0.079
# The closest node selected by the probability distribution is: 22
# And the probability of being selected is 0.079
# The closest node is: 9 and its probability is: 0.456
# The closest node is: 20 and its probability is: 0.404
# The closest node is: 26 and its probability is: 0.14
# The closest node selected by the probability distribution is: 20
# And the probability of being selected is 0.404
# The closest node is: 26 and its probability is: 0.534
# The closest node is: 9 and its probability is: 0.384
# The closest node is: 45 and its probability is: 0.082
# The closest node selected by the probability distribution is: 45
# And the probability of being selected is 0.082
# The closest node is: 44 and its probability is: 0.993
# The closest node is: 31 and its probability is: 0.003
# The closest node is: 43 and its probability is: 0.003
# The closest node selected by the probability distribution is: 44
# And the probability of being selected is 0.993
# The closest node is: 43 and its probability is: 0.354
# The closest node is: 31 and its probability is: 0.33
# The closest node is: 42 and its probability is: 0.316
# The closest node selected by the probability distribution is: 43
# And the probability of being selected is 0.354
# The closest node is: 37 and its probability is: 0.452
# The closest node is: 39 and its probability is: 0.322
# The closest node is: 38 and its probability is: 0.226
# The closest node selected by the probability distribution is: 37
# And the probability of being selected is 0.452
# The closest node is: 39 and its probability is: 0.461
# The closest node is: 38 and its probability is: 0.376
# The closest node is: 40 and its probability is: 0.164
# The closest node selected by the probability distribution is: 38
# And the probability of being selected is 0.376
# The closest node is: 39 and its probability is: 0.989
# The closest node is: 40 and its probability is: 0.005
# The closest node is: 41 and its probability is: 0.005
# The closest node selected by the probability distribution is: 39
# And the probability of being selected is 0.989
# The closest node is: 40 and its probability is: 0.387
# The closest node is: 41 and its probability is: 0.367
# The closest node is: 42 and its probability is: 0.246
# The closest node selected by the probability distribution is: 41
# And the probability of being selected is 0.367
# The closest node is: 40 and its probability is: 0.989
# The closest node is: 35 and its probability is: 0.007
# The closest node is: 42 and its probability is: 0.004
# The closest node selected by the probability distribution is: 35
# And the probability of being selected is 0.007
# The closest node is: 40 and its probability is: 0.47
# The closest node is: 32 and its probability is: 0.308
# The closest node is: 33 and its probability is: 0.221
# The closest node selected by the probability distribution is: 33
# And the probability of being selected is 0.221
# The closest node is: 32 and its probability is: 0.971
# The closest node is: 42 and its probability is: 0.015
# The closest node is: 31 and its probability is: 0.014
# The closest node selected by the probability distribution is: 31
# And the probability of being selected is 0.014
# The closest node is: 42 and its probability is: 0.98
# The closest node is: 40 and its probability is: 0.012
# The closest node is: 32 and its probability is: 0.008
# The closest node selected by the probability distribution is: 32
# And the probability of being selected is 0.008
# The closest node is: 42 and its probability is: 0.435
# The closest node is: 40 and its probability is: 0.368
# The closest node is: 36 and its probability is: 0.197
# The closest node selected by the probability distribution is: 42
# And the probability of being selected is 0.435
# The closest node is: 40 and its probability is: 0.814
# The closest node is: 34 and its probability is: 0.094
# The closest node is: 36 and its probability is: 0.092
# The closest node selected by the probability distribution is: 40
# And the probability of being selected is 0.814
# The closest node is: 36 and its probability is: 0.392
# The closest node is: 4 and its probability is: 0.317
# The closest node is: 5 and its probability is: 0.291
# The closest node selected by the probability distribution is: 4
# And the probability of being selected is 0.317
# The closest node is: 5 and its probability is: 0.986
# The closest node is: 36 and its probability is: 0.011
# The closest node is: 8 and its probability is: 0.004
# The closest node selected by the probability distribution is: 36
# And the probability of being selected is 0.011
# The closest node is: 5 and its probability is: 0.438
# The closest node is: 8 and its probability is: 0.394
# The closest node is: 6 and its probability is: 0.168
# The closest node selected by the probability distribution is: 5
# And the probability of being selected is 0.438
# The closest node is: 8 and its probability is: 0.46
# The closest node is: 6 and its probability is: 0.283
# The closest node is: 7 and its probability is: 0.258
# The closest node selected by the probability distribution is: 7
# And the probability of being selected is 0.258
# The closest node is: 6 and its probability is: 0.973
# The closest node is: 8 and its probability is: 0.022
# The closest node is: 28 and its probability is: 0.006
# The closest node selected by the probability distribution is: 6
# And the probability of being selected is 0.973
# The closest node is: 8 and its probability is: 0.814
# The closest node is: 28 and its probability is: 0.143
# The closest node is: 30 and its probability is: 0.042
# The closest node selected by the probability distribution is: 28
# And the probability of being selected is 0.143
# The closest node is: 30 and its probability is: 0.508
# The closest node is: 8 and its probability is: 0.377
# The closest node is: 34 and its probability is: 0.115
# The closest node selected by the probability distribution is: 34
# And the probability of being selected is 0.115
# The closest node is: 30 and its probability is: 0.6
# The closest node is: 8 and its probability is: 0.321
# The closest node is: 9 and its probability is: 0.08
# The closest node selected by the probability distribution is: 8
# And the probability of being selected is 0.321
# The closest node is: 30 and its probability is: 0.792
# The closest node is: 9 and its probability is: 0.11
# The closest node is: 18 and its probability is: 0.098
# The closest node selected by the probability distribution is: 9
# And the probability of being selected is 0.11
# The closest node is: 26 and its probability is: 0.558
# The closest node is: 18 and its probability is: 0.319
# The closest node is: 12 and its probability is: 0.123
# The closest node selected by the probability distribution is: 18
# And the probability of being selected is 0.319
# The closest node is: 12 and its probability is: 0.414
# The closest node is: 13 and its probability is: 0.293
# The closest node is: 15 and its probability is: 0.292
# The closest node selected by the probability distribution is: 13
# And the probability of being selected is 0.293
# The closest node is: 15 and its probability is: 0.554
# The closest node is: 14 and its probability is: 0.443
# The closest node is: 12 and its probability is: 0.003
# The closest node selected by the probability distribution is: 15
# And the probability of being selected is 0.554
# The closest node is: 14 and its probability is: 0.993
# The closest node is: 12 and its probability is: 0.006
# The closest node is: 26 and its probability is: 0.0
# The closest node selected by the probability distribution is: 12
# And the probability of being selected is 0.006
# The closest node is: 14 and its probability is: 0.94
# The closest node is: 26 and its probability is: 0.045
# The closest node is: 30 and its probability is: 0.014
# The closest node selected by the probability distribution is: 14
# And the probability of being selected is 0.94
# The closest node is: 26 and its probability is: 0.608
# The closest node is: 30 and its probability is: 0.287
# The closest node is: 29 and its probability is: 0.106
# The closest node selected by the probability distribution is: 30
# And the probability of being selected is 0.287
# The closest node is: 29 and its probability is: 0.595
# The closest node is: 26 and its probability is: 0.405
# The closest node selected by the probability distribution is: 29
# And the probability of being selected is 0.595
# The closest node is: 26 and its probability is: 1.0
# The closest node selected by the probability distribution is: 26
# And the probability of being selected is 1.0
# Solution ['23', '27', '24', '21', '1', '10', '16', '2', '17', '3', '25', '11', '19', '22', '20', '45', '44', '43', '37', '38', '39', '41', '35', '33', '31', '32', '42', '40', '4', '36', '5', '7', '6', '28', '34', '8', '9', '18', '13', '15', '12', '14', '30', '29', '26'] takes a total of 974.576
# The closest node is: 6 and its probability is: 0.97
# The closest node is: 8 and its probability is: 0.022
# The closest node is: 28 and its probability is: 0.006
# The closest node is: 36 and its probability is: 0.003
# The closest node selected by the probability distribution is: 8
# And the probability of being selected is 0.022
# The closest node is: 6 and its probability is: 0.651
# The closest node is: 36 and its probability is: 0.184
# The closest node is: 4 and its probability is: 0.084
# The closest node is: 5 and its probability is: 0.081
# The closest node selected by the probability distribution is: 4
# And the probability of being selected is 0.084
# The closest node is: 5 and its probability is: 0.984
# The closest node is: 36 and its probability is: 0.011
# The closest node is: 35 and its probability is: 0.003
# The closest node is: 41 and its probability is: 0.002
# The closest node selected by the probability distribution is: 35
# And the probability of being selected is 0.003
# The closest node is: 41 and its probability is: 0.355
# The closest node is: 40 and its probability is: 0.304
# The closest node is: 32 and its probability is: 0.199
# The closest node is: 33 and its probability is: 0.143
# The closest node selected by the probability distribution is: 40
# And the probability of being selected is 0.304
# The closest node is: 41 and its probability is: 0.991
# The closest node is: 42 and its probability is: 0.004
# The closest node is: 31 and its probability is: 0.003
# The closest node is: 43 and its probability is: 0.002
# The closest node selected by the probability distribution is: 41
# And the probability of being selected is 0.991
# The closest node is: 42 and its probability is: 0.359
# The closest node is: 31 and its probability is: 0.284
# The closest node is: 32 and its probability is: 0.183
# The closest node is: 43 and its probability is: 0.173
# The closest node selected by the probability distribution is: 42
# And the probability of being selected is 0.359
# The closest node is: 31 and its probability is: 0.98
# The closest node is: 32 and its probability is: 0.008
# The closest node is: 33 and its probability is: 0.008
# The closest node is: 43 and its probability is: 0.004
# The closest node selected by the probability distribution is: 31
# And the probability of being selected is 0.98
# The closest node is: 32 and its probability is: 0.351
# The closest node is: 33 and its probability is: 0.32
# The closest node is: 43 and its probability is: 0.18
# The closest node is: 44 and its probability is: 0.15
# The closest node selected by the probability distribution is: 33
# And the probability of being selected is 0.32
# The closest node is: 32 and its probability is: 0.981
# The closest node is: 34 and its probability is: 0.009
# The closest node is: 36 and its probability is: 0.007
# The closest node is: 43 and its probability is: 0.003
# The closest node selected by the probability distribution is: 32
# And the probability of being selected is 0.981
# The closest node is: 36 and its probability is: 0.343
# The closest node is: 34 and its probability is: 0.327
# The closest node is: 43 and its probability is: 0.173
# The closest node is: 37 and its probability is: 0.157
# The closest node selected by the probability distribution is: 43
# And the probability of being selected is 0.173
# The closest node is: 37 and its probability is: 0.426
# The closest node is: 39 and its probability is: 0.303
# The closest node is: 38 and its probability is: 0.213
# The closest node is: 44 and its probability is: 0.058
# The closest node selected by the probability distribution is: 37
# And the probability of being selected is 0.426
# The closest node is: 39 and its probability is: 0.495
# The closest node is: 38 and its probability is: 0.404
# The closest node is: 44 and its probability is: 0.052
# The closest node is: 5 and its probability is: 0.05
# The closest node selected by the probability distribution is: 39
# And the probability of being selected is 0.495
# The closest node is: 38 and its probability is: 0.985
# The closest node is: 2 and its probability is: 0.005
# The closest node is: 10 and its probability is: 0.005
# The closest node is: 16 and its probability is: 0.005
# The closest node selected by the probability distribution is: 10
# And the probability of being selected is 0.005
# The closest node is: 16 and its probability is: 0.703
# The closest node is: 25 and its probability is: 0.122
# The closest node is: 1 and its probability is: 0.121
# The closest node is: 2 and its probability is: 0.054
# The closest node selected by the probability distribution is: 25
# And the probability of being selected is 0.122
# The closest node is: 1 and its probability is: 1.0
# The closest node is: 16 and its probability is: 0.0
# The closest node is: 2 and its probability is: 0.0
# The closest node is: 17 and its probability is: 0.0
# The closest node selected by the probability distribution is: 1
# And the probability of being selected is 1.0
# The closest node is: 16 and its probability is: 0.704
# The closest node is: 2 and its probability is: 0.166
# The closest node is: 17 and its probability is: 0.066
# The closest node is: 3 and its probability is: 0.065
# The closest node selected by the probability distribution is: 16
# And the probability of being selected is 0.704
# The closest node is: 2 and its probability is: 0.705
# The closest node is: 3 and its probability is: 0.143
# The closest node is: 17 and its probability is: 0.108
# The closest node is: 22 and its probability is: 0.043
# The closest node selected by the probability distribution is: 2
# And the probability of being selected is 0.705
# The closest node is: 3 and its probability is: 0.656
# The closest node is: 17 and its probability is: 0.26
# The closest node is: 22 and its probability is: 0.042
# The closest node is: 21 and its probability is: 0.041
# The closest node selected by the probability distribution is: 3
# And the probability of being selected is 0.656
# The closest node is: 17 and its probability is: 0.827
# The closest node is: 11 and its probability is: 0.068
# The closest node is: 18 and its probability is: 0.06
# The closest node is: 22 and its probability is: 0.045
# The closest node selected by the probability distribution is: 17
# And the probability of being selected is 0.827
# The closest node is: 11 and its probability is: 0.407
# The closest node is: 18 and its probability is: 0.28
# The closest node is: 22 and its probability is: 0.157
# The closest node is: 21 and its probability is: 0.156
# The closest node selected by the probability distribution is: 21
# And the probability of being selected is 0.156
# The closest node is: 22 and its probability is: 0.997
# The closest node is: 9 and its probability is: 0.001
# The closest node is: 20 and its probability is: 0.001
# The closest node is: 11 and its probability is: 0.001
# The closest node selected by the probability distribution is: 22
# And the probability of being selected is 0.997
# The closest node is: 9 and its probability is: 0.377
# The closest node is: 20 and its probability is: 0.334
# The closest node is: 11 and its probability is: 0.173
# The closest node is: 26 and its probability is: 0.116
# The closest node selected by the probability distribution is: 9
# And the probability of being selected is 0.377
# The closest node is: 20 and its probability is: 0.36
# The closest node is: 45 and its probability is: 0.26
# The closest node is: 44 and its probability is: 0.256
# The closest node is: 38 and its probability is: 0.123
# The closest node selected by the probability distribution is: 20
# And the probability of being selected is 0.36
# The closest node is: 26 and its probability is: 0.653
# The closest node is: 11 and its probability is: 0.144
# The closest node is: 27 and its probability is: 0.102
# The closest node is: 45 and its probability is: 0.1
# The closest node selected by the probability distribution is: 45
# And the probability of being selected is 0.1
# The closest node is: 44 and its probability is: 0.997
# The closest node is: 38 and its probability is: 0.002
# The closest node is: 34 and its probability is: 0.001
# The closest node is: 36 and its probability is: 0.001
# The closest node selected by the probability distribution is: 36
# And the probability of being selected is 0.001
# The closest node is: 5 and its probability is: 0.595
# The closest node is: 6 and its probability is: 0.229
# The closest node is: 28 and its probability is: 0.088
# The closest node is: 34 and its probability is: 0.088
# The closest node selected by the probability distribution is: 28
# And the probability of being selected is 0.088
# The closest node is: 6 and its probability is: 0.452
# The closest node is: 30 and its probability is: 0.386
# The closest node is: 34 and its probability is: 0.087
# The closest node is: 5 and its probability is: 0.076
# The closest node selected by the probability distribution is: 6
# And the probability of being selected is 0.452
# The closest node is: 5 and its probability is: 0.445
# The closest node is: 30 and its probability is: 0.301
# The closest node is: 34 and its probability is: 0.175
# The closest node is: 38 and its probability is: 0.079
# The closest node selected by the probability distribution is: 34
# And the probability of being selected is 0.175
# The closest node is: 30 and its probability is: 0.53
# The closest node is: 5 and its probability is: 0.185
# The closest node is: 44 and its probability is: 0.168
# The closest node is: 38 and its probability is: 0.118
# The closest node selected by the probability distribution is: 5
# And the probability of being selected is 0.185
# The closest node is: 38 and its probability is: 0.428
# The closest node is: 30 and its probability is: 0.235
# The closest node is: 44 and its probability is: 0.22
# The closest node is: 18 and its probability is: 0.117
# The closest node selected by the probability distribution is: 38
# And the probability of being selected is 0.428
# The closest node is: 44 and its probability is: 0.511
# The closest node is: 11 and its probability is: 0.187
# The closest node is: 18 and its probability is: 0.184
# The closest node is: 19 and its probability is: 0.119
# The closest node selected by the probability distribution is: 44
# And the probability of being selected is 0.511
# The closest node is: 11 and its probability is: 0.302
# The closest node is: 18 and its probability is: 0.26
# The closest node is: 26 and its probability is: 0.232
# The closest node is: 19 and its probability is: 0.205
# The closest node selected by the probability distribution is: 11
# And the probability of being selected is 0.302
# The closest node is: 18 and its probability is: 0.523
# The closest node is: 19 and its probability is: 0.404
# The closest node is: 26 and its probability is: 0.037
# The closest node is: 12 and its probability is: 0.036
# The closest node selected by the probability distribution is: 18
# And the probability of being selected is 0.523
# The closest node is: 19 and its probability is: 0.748
# The closest node is: 12 and its probability is: 0.104
# The closest node is: 13 and its probability is: 0.074
# The closest node is: 15 and its probability is: 0.074
# The closest node selected by the probability distribution is: 13
# And the probability of being selected is 0.074
# The closest node is: 15 and its probability is: 0.553
# The closest node is: 14 and its probability is: 0.443
# The closest node is: 12 and its probability is: 0.003
# The closest node is: 19 and its probability is: 0.0
# The closest node selected by the probability distribution is: 15
# And the probability of being selected is 0.553
# The closest node is: 14 and its probability is: 0.992
# The closest node is: 12 and its probability is: 0.006
# The closest node is: 19 and its probability is: 0.001
# The closest node is: 26 and its probability is: 0.0
# The closest node selected by the probability distribution is: 12
# And the probability of being selected is 0.006
# The closest node is: 14 and its probability is: 0.732
# The closest node is: 19 and its probability is: 0.213
# The closest node is: 26 and its probability is: 0.035
# The closest node is: 27 and its probability is: 0.02
# The closest node selected by the probability distribution is: 14
# And the probability of being selected is 0.732
# The closest node is: 19 and its probability is: 0.667
# The closest node is: 26 and its probability is: 0.156
# The closest node is: 27 and its probability is: 0.09
# The closest node is: 23 and its probability is: 0.088
# The closest node selected by the probability distribution is: 23
# And the probability of being selected is 0.088
# The closest node is: 24 and its probability is: 0.666
# The closest node is: 27 and its probability is: 0.333
# The closest node is: 26 and its probability is: 0.001
# The closest node is: 19 and its probability is: 0.0
# The closest node selected by the probability distribution is: 19
# And the probability of being selected is 0.0
# The closest node is: 26 and its probability is: 0.535
# The closest node is: 27 and its probability is: 0.203
# The closest node is: 24 and its probability is: 0.191
# The closest node is: 30 and its probability is: 0.071
# The closest node selected by the probability distribution is: 24
# And the probability of being selected is 0.191
# The closest node is: 27 and its probability is: 0.994
# The closest node is: 26 and its probability is: 0.006
# The closest node is: 30 and its probability is: 0.0
# The closest node is: 29 and its probability is: 0.0
# The closest node selected by the probability distribution is: 26
# And the probability of being selected is 0.006
# The closest node is: 27 and its probability is: 0.913
# The closest node is: 30 and its probability is: 0.053
# The closest node is: 29 and its probability is: 0.034
# The closest node selected by the probability distribution is: 27
# And the probability of being selected is 0.913
# The closest node is: 30 and its probability is: 0.546
# The closest node is: 29 and its probability is: 0.454
# The closest node selected by the probability distribution is: 29
# And the probability of being selected is 0.454
# The closest node is: 30 and its probability is: 1.0
# The closest node selected by the probability distribution is: 30
# And the probability of being selected is 1.0
# 6.708203932499369
# 1e-08
# Best fitness obtained:  533.674
# Improvement over randomized greedy heuristic:  0.5056

# %% [markdown]
# **(TO DO) Q6 - 2 marks**
# Try the annealing again, but provide a different temperature schedule, by changing alpha, and the starting and stopping temperatures.  These are all parameters to the class which can be set.  Try also changing the number of iterations to do.  Explore 4 variations below.

# %%
# (TO DO) Look at this line from the SimAnneal class above
# def __init__(self, nodes, randomizedGreedy, k=4, T=-1, alpha=-1, stopping_T=-1, stopping_iter=-1):
# This means that parameters k, T, alpha, stopping_T and stopping_iter all have defaults, but could be changed
# For example, calling SimAnneal(manyCities, False, stopping_iter=100) means that I set a maximum of 100 iterations for a 
# Greedy solution. Calling  SimAnneal(manyCities, True, k=3, stopping_iter=100) is the same for a randomized greedy solution
# with k = 3.
# Try four variations and look at the differences
# The key point of this question is to use different parameters to understand how they work
# What you need to do is create and run these four different examples

# Test 1 (Use a Greedy solution, see comment above) ...
sa = SimAnneal(manyCities, False, stopping_iter=100)
betterSol = sa.anneal()
sa.plot_learning()
showPath(betterSol, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])

# Test 2 (Use a Randomized Greedy solution, see comment above)...
sa = SimAnneal(manyCities, True, k=3, stopping_iter=100)
betterSol = sa.anneal()
sa.plot_learning()
showPath(betterSol, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])

# Test 3 (Use a Greedy solution, see comment above)...
sa = SimAnneal(manyCities, False, T=20)
betterSol = sa.anneal()
sa.plot_learning()
showPath(betterSol, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])


# Test 4 (Use a Randomized Greedy solution, see comment above)...
sa = SimAnneal(manyCities, True, k=6, T=20, alpha=0.888)
betterSol = sa.anneal()
sa.plot_learning()
showPath(betterSol, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])
# Out:
# 6.708203932499369
# 1e-08
# Best fitness obtained:  557.707
# Improvement over greedy heuristic:  0.0006
# The closest node is: 15 and its probability is: 0.554
# The closest node is: 14 and its probability is: 0.443
# The closest node is: 12 and its probability is: 0.003
# The closest node selected by the probability distribution is: 15
# And the probability of being selected is 0.554
# The closest node is: 14 and its probability is: 0.992
# The closest node is: 12 and its probability is: 0.006
# The closest node is: 18 and its probability is: 0.001
# The closest node selected by the probability distribution is: 18
# And the probability of being selected is 0.001
# The closest node is: 11 and its probability is: 0.446
# The closest node is: 19 and its probability is: 0.359
# The closest node is: 17 and its probability is: 0.196
# The closest node selected by the probability distribution is: 17
# And the probability of being selected is 0.196
# The closest node is: 3 and its probability is: 0.554
# The closest node is: 2 and its probability is: 0.274
# The closest node is: 16 and its probability is: 0.173
# The closest node selected by the probability distribution is: 16
# And the probability of being selected is 0.173
# The closest node is: 10 and its probability is: 0.761
# The closest node is: 25 and its probability is: 0.12
# The closest node is: 1 and its probability is: 0.119
# The closest node selected by the probability distribution is: 25
# And the probability of being selected is 0.12
# The closest node is: 1 and its probability is: 1.0
# The closest node is: 10 and its probability is: 0.0
# The closest node is: 2 and its probability is: 0.0
# The closest node selected by the probability distribution is: 1
# And the probability of being selected is 1.0
# The closest node is: 10 and its probability is: 0.771
# The closest node is: 2 and its probability is: 0.165
# The closest node is: 3 and its probability is: 0.064
# The closest node selected by the probability distribution is: 2
# And the probability of being selected is 0.165
# The closest node is: 3 and its probability is: 0.484
# The closest node is: 10 and its probability is: 0.484
# The closest node is: 22 and its probability is: 0.031
# The closest node selected by the probability distribution is: 3
# And the probability of being selected is 0.484
# The closest node is: 10 and its probability is: 0.699
# The closest node is: 11 and its probability is: 0.181
# The closest node is: 22 and its probability is: 0.12
# The closest node selected by the probability distribution is: 11
# And the probability of being selected is 0.181
# The closest node is: 19 and its probability is: 0.659
# The closest node is: 10 and its probability is: 0.198
# The closest node is: 21 and its probability is: 0.143
# The closest node selected by the probability distribution is: 10
# And the probability of being selected is 0.198
# The closest node is: 22 and its probability is: 0.419
# The closest node is: 21 and its probability is: 0.4
# The closest node is: 38 and its probability is: 0.181
# The closest node selected by the probability distribution is: 21
# And the probability of being selected is 0.4
# The closest node is: 22 and its probability is: 0.998
# The closest node is: 9 and its probability is: 0.001
# The closest node is: 20 and its probability is: 0.001
# The closest node selected by the probability distribution is: 22
# And the probability of being selected is 0.998
# The closest node is: 9 and its probability is: 0.456
# The closest node is: 20 and its probability is: 0.404
# The closest node is: 26 and its probability is: 0.14
# The closest node selected by the probability distribution is: 9
# And the probability of being selected is 0.456
# The closest node is: 20 and its probability is: 0.411
# The closest node is: 45 and its probability is: 0.297
# The closest node is: 44 and its probability is: 0.292
# The closest node selected by the probability distribution is: 44
# And the probability of being selected is 0.292
# The closest node is: 45 and its probability is: 0.993
# The closest node is: 43 and its probability is: 0.004
# The closest node is: 31 and its probability is: 0.003
# The closest node selected by the probability distribution is: 45
# And the probability of being selected is 0.993
# The closest node is: 31 and its probability is: 0.339
# The closest node is: 43 and its probability is: 0.339
# The closest node is: 42 and its probability is: 0.323
# The closest node selected by the probability distribution is: 43
# And the probability of being selected is 0.339
# The closest node is: 37 and its probability is: 0.452
# The closest node is: 39 and its probability is: 0.322
# The closest node is: 38 and its probability is: 0.226
# The closest node selected by the probability distribution is: 39
# And the probability of being selected is 0.322
# The closest node is: 38 and its probability is: 0.958
# The closest node is: 37 and its probability is: 0.036
# The closest node is: 40 and its probability is: 0.006
# The closest node selected by the probability distribution is: 40
# And the probability of being selected is 0.006
# The closest node is: 41 and its probability is: 0.99
# The closest node is: 35 and its probability is: 0.006
# The closest node is: 42 and its probability is: 0.004
# The closest node selected by the probability distribution is: 42
# And the probability of being selected is 0.004
# The closest node is: 31 and its probability is: 0.976
# The closest node is: 41 and its probability is: 0.015
# The closest node is: 32 and its probability is: 0.008
# The closest node selected by the probability distribution is: 41
# And the probability of being selected is 0.015
# The closest node is: 35 and its probability is: 0.591
# The closest node is: 31 and its probability is: 0.249
# The closest node is: 32 and its probability is: 0.16
# The closest node selected by the probability distribution is: 32
# And the probability of being selected is 0.16
# The closest node is: 33 and its probability is: 0.953
# The closest node is: 35 and its probability is: 0.031
# The closest node is: 31 and its probability is: 0.015
# The closest node selected by the probability distribution is: 31
# And the probability of being selected is 0.015
# The closest node is: 33 and its probability is: 0.434
# The closest node is: 35 and its probability is: 0.408
# The closest node is: 37 and its probability is: 0.158
# The closest node selected by the probability distribution is: 35
# And the probability of being selected is 0.408
# The closest node is: 33 and its probability is: 0.556
# The closest node is: 36 and its probability is: 0.276
# The closest node is: 37 and its probability is: 0.168
# The closest node selected by the probability distribution is: 36
# And the probability of being selected is 0.276
# The closest node is: 4 and its probability is: 0.382
# The closest node is: 5 and its probability is: 0.325
# The closest node is: 8 and its probability is: 0.293
# The closest node selected by the probability distribution is: 8
# And the probability of being selected is 0.293
# The closest node is: 6 and its probability is: 0.531
# The closest node is: 7 and its probability is: 0.401
# The closest node is: 4 and its probability is: 0.068
# The closest node selected by the probability distribution is: 7
# And the probability of being selected is 0.401
# The closest node is: 6 and its probability is: 0.992
# The closest node is: 28 and its probability is: 0.006
# The closest node is: 4 and its probability is: 0.002
# The closest node selected by the probability distribution is: 6
# And the probability of being selected is 0.992
# The closest node is: 28 and its probability is: 0.534
# The closest node is: 4 and its probability is: 0.233
# The closest node is: 5 and its probability is: 0.233
# The closest node selected by the probability distribution is: 4
# And the probability of being selected is 0.233
# The closest node is: 5 and its probability is: 0.996
# The closest node is: 37 and its probability is: 0.002
# The closest node is: 33 and its probability is: 0.002
# The closest node selected by the probability distribution is: 37
# And the probability of being selected is 0.002
# The closest node is: 38 and its probability is: 0.816
# The closest node is: 5 and its probability is: 0.1
# The closest node is: 33 and its probability is: 0.084
# The closest node selected by the probability distribution is: 33
# And the probability of being selected is 0.084
# The closest node is: 34 and its probability is: 0.63
# The closest node is: 5 and its probability is: 0.223
# The closest node is: 30 and its probability is: 0.147
# The closest node selected by the probability distribution is: 34
# And the probability of being selected is 0.63
# The closest node is: 30 and its probability is: 0.546
# The closest node is: 28 and its probability is: 0.263
# The closest node is: 5 and its probability is: 0.191
# The closest node selected by the probability distribution is: 5
# And the probability of being selected is 0.191
# The closest node is: 38 and its probability is: 0.425
# The closest node is: 28 and its probability is: 0.341
# The closest node is: 30 and its probability is: 0.233
# The closest node selected by the probability distribution is: 28
# And the probability of being selected is 0.341
# The closest node is: 30 and its probability is: 0.922
# The closest node is: 38 and its probability is: 0.057
# The closest node is: 14 and its probability is: 0.021
# The closest node selected by the probability distribution is: 14
# And the probability of being selected is 0.021
# The closest node is: 12 and its probability is: 0.826
# The closest node is: 19 and its probability is: 0.126
# The closest node is: 38 and its probability is: 0.048
# The closest node selected by the probability distribution is: 38
# And the probability of being selected is 0.048
# The closest node is: 20 and its probability is: 0.387
# The closest node is: 19 and its probability is: 0.374
# The closest node is: 26 and its probability is: 0.238
# The closest node selected by the probability distribution is: 26
# And the probability of being selected is 0.238
# The closest node is: 20 and its probability is: 0.621
# The closest node is: 27 and its probability is: 0.199
# The closest node is: 23 and its probability is: 0.18
# The closest node selected by the probability distribution is: 20
# And the probability of being selected is 0.621
# The closest node is: 27 and its probability is: 0.35
# The closest node is: 23 and its probability is: 0.328
# The closest node is: 19 and its probability is: 0.322
# The closest node selected by the probability distribution is: 27
# And the probability of being selected is 0.35
# The closest node is: 23 and its probability is: 0.714
# The closest node is: 24 and its probability is: 0.286
# The closest node is: 19 and its probability is: 0.0
# The closest node selected by the probability distribution is: 24
# And the probability of being selected is 0.286
# The closest node is: 23 and its probability is: 1.0
# The closest node is: 19 and its probability is: 0.0
# The closest node is: 12 and its probability is: 0.0
# The closest node selected by the probability distribution is: 19
# And the probability of being selected is 0.0
# The closest node is: 12 and its probability is: 0.814
# The closest node is: 23 and its probability is: 0.136
# The closest node is: 30 and its probability is: 0.05
# The closest node selected by the probability distribution is: 23
# And the probability of being selected is 0.136
# The closest node is: 12 and its probability is: 0.575
# The closest node is: 30 and its probability is: 0.231
# The closest node is: 29 and its probability is: 0.194
# The closest node selected by the probability distribution is: 29
# And the probability of being selected is 0.194
# The closest node is: 30 and its probability is: 0.785
# The closest node is: 12 and its probability is: 0.215
# The closest node selected by the probability distribution is: 30
# And the probability of being selected is 0.785
# The closest node is: 12 and its probability is: 1.0
# The closest node selected by the probability distribution is: 12
# And the probability of being selected is 1.0
# 6.708203932499369
# 1e-08
# Best fitness obtained:  1045.306
# Improvement over randomized greedy heuristic:  0.1182
# 20
# 1e-08
# Best fitness obtained:  579.337
# Improvement over greedy heuristic:  0.079
# The closest node is: 23 and its probability is: 0.712
# The closest node is: 24 and its probability is: 0.285
# The closest node is: 26 and its probability is: 0.002
# The closest node is: 20 and its probability is: 0.001
# The closest node is: 21 and its probability is: 0.001
# The closest node is: 22 and its probability is: 0.001
# The closest node selected by the probability distribution is: 23
# And the probability of being selected is 0.712
# The closest node is: 24 and its probability is: 0.997
# The closest node is: 26 and its probability is: 0.001
# The closest node is: 20 and its probability is: 0.001
# The closest node is: 21 and its probability is: 0.0
# The closest node is: 22 and its probability is: 0.0
# The closest node is: 9 and its probability is: 0.0
# The closest node selected by the probability distribution is: 22
# And the probability of being selected is 0.0
# The closest node is: 21 and its probability is: 0.991
# The closest node is: 1 and its probability is: 0.002
# The closest node is: 25 and its probability is: 0.002
# The closest node is: 10 and its probability is: 0.002
# The closest node is: 16 and its probability is: 0.002
# The closest node is: 9 and its probability is: 0.001
# The closest node selected by the probability distribution is: 1
# And the probability of being selected is 0.002
# The closest node is: 25 and its probability is: 1.0
# The closest node is: 10 and its probability is: 0.0
# The closest node is: 16 and its probability is: 0.0
# The closest node is: 2 and its probability is: 0.0
# The closest node is: 17 and its probability is: 0.0
# The closest node is: 3 and its probability is: 0.0
# The closest node selected by the probability distribution is: 17
# And the probability of being selected is 0.0
# The closest node is: 3 and its probability is: 0.409
# The closest node is: 2 and its probability is: 0.202
# The closest node is: 16 and its probability is: 0.127
# The closest node is: 10 and its probability is: 0.098
# The closest node is: 25 and its probability is: 0.098
# The closest node is: 11 and its probability is: 0.065
# The closest node selected by the probability distribution is: 11
# And the probability of being selected is 0.065
# The closest node is: 18 and its probability is: 0.345
# The closest node is: 19 and its probability is: 0.266
# The closest node is: 3 and its probability is: 0.114
# The closest node is: 2 and its probability is: 0.094
# The closest node is: 25 and its probability is: 0.093
# The closest node is: 16 and its probability is: 0.089
# The closest node selected by the probability distribution is: 25
# And the probability of being selected is 0.093
# The closest node is: 10 and its probability is: 0.437
# The closest node is: 16 and its probability is: 0.397
# The closest node is: 2 and its probability is: 0.093
# The closest node is: 3 and its probability is: 0.036
# The closest node is: 21 and its probability is: 0.03
# The closest node is: 38 and its probability is: 0.007
# The closest node selected by the probability distribution is: 2
# And the probability of being selected is 0.093
# The closest node is: 16 and its probability is: 0.43
# The closest node is: 3 and its probability is: 0.264
# The closest node is: 10 and its probability is: 0.264
# The closest node is: 21 and its probability is: 0.017
# The closest node is: 38 and its probability is: 0.013
# The closest node is: 39 and its probability is: 0.012
# The closest node selected by the probability distribution is: 10
# And the probability of being selected is 0.264
# The closest node is: 16 and its probability is: 0.964
# The closest node is: 3 and its probability is: 0.019
# The closest node is: 21 and its probability is: 0.008
# The closest node is: 38 and its probability is: 0.003
# The closest node is: 39 and its probability is: 0.003
# The closest node is: 18 and its probability is: 0.002
# The closest node selected by the probability distribution is: 38
# And the probability of being selected is 0.003
# The closest node is: 39 and its probability is: 0.931
# The closest node is: 37 and its probability is: 0.029
# The closest node is: 43 and its probability is: 0.025
# The closest node is: 40 and its probability is: 0.005
# The closest node is: 16 and its probability is: 0.005
# The closest node is: 3 and its probability is: 0.005
# The closest node selected by the probability distribution is: 37
# And the probability of being selected is 0.029
# The closest node is: 43 and its probability is: 0.414
# The closest node is: 39 and its probability is: 0.289
# The closest node is: 40 and its probability is: 0.103
# The closest node is: 41 and its probability is: 0.096
# The closest node is: 35 and its probability is: 0.054
# The closest node is: 42 and its probability is: 0.044
# The closest node selected by the probability distribution is: 35
# And the probability of being selected is 0.054
# The closest node is: 41 and its probability is: 0.3
# The closest node is: 40 and its probability is: 0.257
# The closest node is: 32 and its probability is: 0.169
# The closest node is: 33 and its probability is: 0.121
# The closest node is: 42 and its probability is: 0.082
# The closest node is: 31 and its probability is: 0.07
# The closest node selected by the probability distribution is: 32
# And the probability of being selected is 0.169
# The closest node is: 33 and its probability is: 0.933
# The closest node is: 42 and its probability is: 0.016
# The closest node is: 31 and its probability is: 0.015
# The closest node is: 41 and its probability is: 0.015
# The closest node is: 40 and its probability is: 0.014
# The closest node is: 36 and its probability is: 0.007
# The closest node selected by the probability distribution is: 33
# And the probability of being selected is 0.933
# The closest node is: 42 and its probability is: 0.218
# The closest node is: 31 and its probability is: 0.207
# The closest node is: 41 and its probability is: 0.18
# The closest node is: 40 and its probability is: 0.168
# The closest node is: 34 and its probability is: 0.126
# The closest node is: 36 and its probability is: 0.101
# The closest node selected by the probability distribution is: 41
# And the probability of being selected is 0.18
# The closest node is: 40 and its probability is: 0.99
# The closest node is: 42 and its probability is: 0.004
# The closest node is: 31 and its probability is: 0.003
# The closest node is: 43 and its probability is: 0.002
# The closest node is: 39 and its probability is: 0.001
# The closest node is: 36 and its probability is: 0.001
# The closest node selected by the probability distribution is: 43
# And the probability of being selected is 0.002
# The closest node is: 39 and its probability is: 0.448
# The closest node is: 40 and its probability is: 0.191
# The closest node is: 42 and its probability is: 0.104
# The closest node is: 31 and its probability is: 0.095
# The closest node is: 44 and its probability is: 0.086
# The closest node is: 45 and its probability is: 0.076
# The closest node selected by the probability distribution is: 40
# And the probability of being selected is 0.191
# The closest node is: 42 and its probability is: 0.404
# The closest node is: 31 and its probability is: 0.321
# The closest node is: 39 and its probability is: 0.084
# The closest node is: 36 and its probability is: 0.074
# The closest node is: 4 and its probability is: 0.059
# The closest node is: 44 and its probability is: 0.058
# The closest node selected by the probability distribution is: 4
# And the probability of being selected is 0.059
# The closest node is: 5 and its probability is: 0.98
# The closest node is: 36 and its probability is: 0.011
# The closest node is: 8 and its probability is: 0.004
# The closest node is: 6 and its probability is: 0.002
# The closest node is: 7 and its probability is: 0.002
# The closest node is: 42 and its probability is: 0.001
# The closest node selected by the probability distribution is: 42
# And the probability of being selected is 0.001
# The closest node is: 31 and its probability is: 0.988
# The closest node is: 44 and its probability is: 0.003
# The closest node is: 45 and its probability is: 0.003
# The closest node is: 39 and its probability is: 0.002
# The closest node is: 34 and its probability is: 0.002
# The closest node is: 36 and its probability is: 0.002
# The closest node selected by the probability distribution is: 45
# And the probability of being selected is 0.003
# The closest node is: 44 and its probability is: 0.99
# The closest node is: 31 and its probability is: 0.003
# The closest node is: 39 and its probability is: 0.002
# The closest node is: 9 and its probability is: 0.002
# The closest node is: 16 and its probability is: 0.001
# The closest node is: 21 and its probability is: 0.001
# The closest node selected by the probability distribution is: 21
# And the probability of being selected is 0.001
# The closest node is: 16 and its probability is: 0.302
# The closest node is: 9 and its probability is: 0.22
# The closest node is: 20 and its probability is: 0.21
# The closest node is: 3 and its probability is: 0.135
# The closest node is: 26 and its probability is: 0.073
# The closest node is: 39 and its probability is: 0.06
# The closest node selected by the probability distribution is: 20
# And the probability of being selected is 0.21
# The closest node is: 26 and its probability is: 0.4
# The closest node is: 9 and its probability is: 0.288
# The closest node is: 16 and its probability is: 0.115
# The closest node is: 3 and its probability is: 0.078
# The closest node is: 44 and its probability is: 0.061
# The closest node is: 19 and its probability is: 0.058
# The closest node selected by the probability distribution is: 26
# And the probability of being selected is 0.4
# The closest node is: 24 and its probability is: 0.257
# The closest node is: 9 and its probability is: 0.198
# The closest node is: 16 and its probability is: 0.154
# The closest node is: 19 and its probability is: 0.149
# The closest node is: 3 and its probability is: 0.123
# The closest node is: 18 and its probability is: 0.119
# The closest node selected by the probability distribution is: 24
# And the probability of being selected is 0.257
# The closest node is: 9 and its probability is: 0.227
# The closest node is: 19 and its probability is: 0.184
# The closest node is: 16 and its probability is: 0.169
# The closest node is: 18 and its probability is: 0.152
# The closest node is: 3 and its probability is: 0.148
# The closest node is: 44 and its probability is: 0.121
# The closest node selected by the probability distribution is: 16
# And the probability of being selected is 0.169
# The closest node is: 3 and its probability is: 0.698
# The closest node is: 39 and its probability is: 0.086
# The closest node is: 18 and its probability is: 0.073
# The closest node is: 9 and its probability is: 0.06
# The closest node is: 19 and its probability is: 0.044
# The closest node is: 44 and its probability is: 0.039
# The closest node selected by the probability distribution is: 19
# And the probability of being selected is 0.044
# The closest node is: 18 and its probability is: 0.641
# The closest node is: 3 and its probability is: 0.107
# The closest node is: 12 and its probability is: 0.096
# The closest node is: 13 and its probability is: 0.054
# The closest node is: 15 and its probability is: 0.053
# The closest node is: 14 and its probability is: 0.05
# The closest node selected by the probability distribution is: 14
# And the probability of being selected is 0.05
# The closest node is: 13 and its probability is: 0.498
# The closest node is: 15 and its probability is: 0.498
# The closest node is: 12 and its probability is: 0.003
# The closest node is: 18 and its probability is: 0.001
# The closest node is: 3 and its probability is: 0.0
# The closest node is: 39 and its probability is: 0.0
# The closest node selected by the probability distribution is: 3
# And the probability of being selected is 0.0
# The closest node is: 18 and its probability is: 0.405
# The closest node is: 39 and its probability is: 0.261
# The closest node is: 9 and its probability is: 0.117
# The closest node is: 44 and its probability is: 0.094
# The closest node is: 12 and its probability is: 0.062
# The closest node is: 31 and its probability is: 0.061
# The closest node selected by the probability distribution is: 12
# And the probability of being selected is 0.062
# The closest node is: 13 and its probability is: 0.449
# The closest node is: 15 and its probability is: 0.395
# The closest node is: 18 and its probability is: 0.105
# The closest node is: 39 and its probability is: 0.021
# The closest node is: 9 and its probability is: 0.015
# The closest node is: 5 and its probability is: 0.014
# The closest node selected by the probability distribution is: 18
# And the probability of being selected is 0.105
# The closest node is: 13 and its probability is: 0.251
# The closest node is: 15 and its probability is: 0.25
# The closest node is: 39 and its probability is: 0.191
# The closest node is: 9 and its probability is: 0.133
# The closest node is: 44 and its probability is: 0.099
# The closest node is: 5 and its probability is: 0.076
# The closest node selected by the probability distribution is: 13
# And the probability of being selected is 0.251
# The closest node is: 15 and its probability is: 0.999
# The closest node is: 39 and its probability is: 0.0
# The closest node is: 5 and its probability is: 0.0
# The closest node is: 9 and its probability is: 0.0
# The closest node is: 36 and its probability is: 0.0
# The closest node is: 44 and its probability is: 0.0
# The closest node selected by the probability distribution is: 39
# And the probability of being selected is 0.0
# The closest node is: 44 and its probability is: 0.308
# The closest node is: 31 and its probability is: 0.239
# The closest node is: 5 and its probability is: 0.138
# The closest node is: 9 and its probability is: 0.133
# The closest node is: 36 and its probability is: 0.117
# The closest node is: 8 and its probability is: 0.066
# The closest node selected by the probability distribution is: 9
# And the probability of being selected is 0.133
# The closest node is: 44 and its probability is: 0.559
# The closest node is: 31 and its probability is: 0.174
# The closest node is: 36 and its probability is: 0.072
# The closest node is: 5 and its probability is: 0.072
# The closest node is: 34 and its probability is: 0.071
# The closest node is: 8 and its probability is: 0.052
# The closest node selected by the probability distribution is: 44
# And the probability of being selected is 0.559
# The closest node is: 31 and its probability is: 0.574
# The closest node is: 34 and its probability is: 0.11
# The closest node is: 36 and its probability is: 0.105
# The closest node is: 5 and its probability is: 0.093
# The closest node is: 8 and its probability is: 0.065
# The closest node is: 6 and its probability is: 0.053
# The closest node selected by the probability distribution is: 8
# And the probability of being selected is 0.065
# The closest node is: 6 and its probability is: 0.43
# The closest node is: 7 and its probability is: 0.325
# The closest node is: 36 and its probability is: 0.122
# The closest node is: 5 and its probability is: 0.054
# The closest node is: 28 and its probability is: 0.048
# The closest node is: 30 and its probability is: 0.021
# The closest node selected by the probability distribution is: 5
# And the probability of being selected is 0.054
# The closest node is: 36 and its probability is: 0.568
# The closest node is: 6 and its probability is: 0.139
# The closest node is: 7 and its probability is: 0.127
# The closest node is: 31 and its probability is: 0.068
# The closest node is: 28 and its probability is: 0.053
# The closest node is: 34 and its probability is: 0.045
# The closest node selected by the probability distribution is: 34
# And the probability of being selected is 0.045
# The closest node is: 30 and its probability is: 0.259
# The closest node is: 31 and its probability is: 0.225
# The closest node is: 36 and its probability is: 0.171
# The closest node is: 28 and its probability is: 0.125
# The closest node is: 6 and its probability is: 0.111
# The closest node is: 7 and its probability is: 0.11
# The closest node selected by the probability distribution is: 36
# And the probability of being selected is 0.171
# The closest node is: 6 and its probability is: 0.325
# The closest node is: 7 and its probability is: 0.293
# The closest node is: 31 and its probability is: 0.148
# The closest node is: 28 and its probability is: 0.125
# The closest node is: 30 and its probability is: 0.092
# The closest node is: 15 and its probability is: 0.016
# The closest node selected by the probability distribution is: 28
# And the probability of being selected is 0.125
# The closest node is: 7 and its probability is: 0.364
# The closest node is: 6 and its probability is: 0.321
# The closest node is: 30 and its probability is: 0.274
# The closest node is: 31 and its probability is: 0.029
# The closest node is: 15 and its probability is: 0.006
# The closest node is: 29 and its probability is: 0.005
# The closest node selected by the probability distribution is: 6
# And the probability of being selected is 0.321
# The closest node is: 7 and its probability is: 0.998
# The closest node is: 30 and its probability is: 0.002
# The closest node is: 31 and its probability is: 0.001
# The closest node is: 15 and its probability is: 0.0
# The closest node is: 29 and its probability is: 0.0
# The closest node selected by the probability distribution is: 31
# And the probability of being selected is 0.001
# The closest node is: 7 and its probability is: 0.421
# The closest node is: 30 and its probability is: 0.394
# The closest node is: 15 and its probability is: 0.111
# The closest node is: 29 and its probability is: 0.075
# The closest node selected by the probability distribution is: 30
# And the probability of being selected is 0.394
# The closest node is: 7 and its probability is: 0.887
# The closest node is: 29 and its probability is: 0.064
# The closest node is: 15 and its probability is: 0.049
# The closest node selected by the probability distribution is: 29
# And the probability of being selected is 0.064
# The closest node is: 7 and its probability is: 0.7
# The closest node is: 15 and its probability is: 0.3
# The closest node selected by the probability distribution is: 15
# And the probability of being selected is 0.3
# The closest node is: 7 and its probability is: 1.0
# The closest node selected by the probability distribution is: 7
# And the probability of being selected is 1.0
# 20
# 1e-08
# Best fitness obtained:  1099.262
# Improvement over randomized greedy heuristic:  0.1907

# %% [markdown]
# ***SIGNATURE:***
# My name is Fatemeh Soltani.
# My student number is 300139153.
# I certify being the author of this assignment.
